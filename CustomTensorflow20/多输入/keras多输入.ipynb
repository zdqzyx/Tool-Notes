# %% [markdown]
# ## fit传递列表

# %%
from tensorflow.keras.layers import Input, MaxPool1D, Conv1D, Flatten, Dense, concatenate
from tensorflow.keras import Model
from tensorflow.keras.utils import plot_model
import numpy as np

def multi_input_model():
    """构建多输入模型"""
    input1_= Input(shape=(100, 1), name='input1')
    input2_ = Input(shape=(50, 1), name='input2')
 
    x1 = Conv1D(16, kernel_size=3, strides=1, activation='relu', padding='same')(input1_)
    x1 = MaxPool1D(pool_size=10, strides=10)(x1)
 
    x2 = Conv1D(16, kernel_size=3, strides=1, activation='relu', padding='same')(input2_)
    x2 = MaxPool1D(pool_size=5, strides=5)(x2)
 
    x = concatenate([x1, x2])
    x = Flatten()(x)
 
    x = Dense(10, activation='relu')(x)
    output_ = Dense(1, activation='sigmoid', name='output')(x)
 
    model = Model(inputs=[input1_, input2_], outputs=[output_])
    model.summary()
 
    return model
 
if __name__ == '__main__':
    # 产生训练数据
    x1 = np.random.rand(100, 100, 1)
    x2 = np.random.rand(100, 50, 1)
    # 产生标签
    y = np.random.randint(0, 2, (100,))
    
    inp = {'input1':x1, 'input2':x2}
 
    model = multi_input_model()
    # 保存模型图
    plot_model(model, 'Multi_input_model.png')
 
    model.compile(optimizer='adam', loss='binary_crossentropy')
    model.fit([x1, x2], y, epochs=10, batch_size=10)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input1 (InputLayer)             [(None, 100, 1)]     0
# __________________________________________________________________________________________________
# input2 (InputLayer)             [(None, 50, 1)]      0
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 100, 16)      64          input1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 50, 16)       64          input2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 10, 16)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 10, 16)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 10, 32)       0           max_pooling1d_2[0][0]
#                                                                  max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 320)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           3210        flatten_1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            11          dense_1[0][0]
# ==================================================================================================
# Total params: 3,349
# Trainable params: 3,349
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.
# Train on 100 samples
# Epoch 1/10
# 100/100 [==============================] - 0s 4ms/sample - loss: 0.7092
# Epoch 2/10
# 100/100 [==============================] - 0s 170us/sample - loss: 0.6929
# Epoch 3/10
# 100/100 [==============================] - 0s 180us/sample - loss: 0.6927
# Epoch 4/10
# 100/100 [==============================] - 0s 180us/sample - loss: 0.6924
# Epoch 5/10
# 100/100 [==============================] - 0s 180us/sample - loss: 0.6923
# Epoch 6/10
# 100/100 [==============================] - 0s 189us/sample - loss: 0.6922
# Epoch 7/10
# 100/100 [==============================] - 0s 180us/sample - loss: 0.6921
# Epoch 8/10
# 100/100 [==============================] - 0s 219us/sample - loss: 0.6919
# Epoch 9/10
# 100/100 [==============================] - 0s 170us/sample - loss: 0.6919
# Epoch 10/10
# 100/100 [==============================] - 0s 170us/sample - loss: 0.6917

# %% [markdown]
# ## fit传递字典，需要和Input()的name匹配

# %%
from tensorflow.keras.layers import Input, MaxPool1D, Conv1D, Flatten, Dense, concatenate
from tensorflow.keras import Model
from tensorflow.keras.utils import plot_model
import numpy as np

def multi_input_model():
    """构建多输入模型"""
    input1_= Input(shape=(100, 1), name='input1')
    input2_ = Input(shape=(50, 1), name='input2')
 
    x1 = Conv1D(16, kernel_size=3, strides=1, activation='relu', padding='same')(input1_)
    x1 = MaxPool1D(pool_size=10, strides=10)(x1)
 
    x2 = Conv1D(16, kernel_size=3, strides=1, activation='relu', padding='same')(input2_)
    x2 = MaxPool1D(pool_size=5, strides=5)(x2)
 
    x = concatenate([x1, x2])
    x = Flatten()(x)
 
    x = Dense(10, activation='relu')(x)
    output_ = Dense(1, activation='sigmoid', name='output')(x)
 
    model = Model(inputs=[input1_, input2_], outputs=[output_])
    model.summary()
 
    return model
 
if __name__ == '__main__':
    # 产生训练数据
    x1 = np.random.rand(100, 100, 1)
    x2 = np.random.rand(100, 50, 1)
    # 产生标签
    y = np.random.randint(0, 2, (100,))
    
    inp = {'input1':x1, 'input2':x2}
 
    model = multi_input_model()
    # 保存模型图
    plot_model(model, 'Multi_input_model.png')
 
    model.compile(optimizer='adam', loss='binary_crossentropy')
#     model.fit([x1, x2], y, epochs=10, batch_size=10)
    model.fit(inp, y, epochs=10, batch_size=10)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input1 (InputLayer)             [(None, 100, 1)]     0
# __________________________________________________________________________________________________
# input2 (InputLayer)             [(None, 50, 1)]      0
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 100, 16)      64          input1[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 50, 16)       64          input2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_12 (MaxPooling1D) (None, 10, 16)       0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_13 (MaxPooling1D) (None, 10, 16)       0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 10, 32)       0           max_pooling1d_12[0][0]
#                                                                  max_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 320)          0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 10)           3210        flatten_5[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            11          dense_5[0][0]
# ==================================================================================================
# Total params: 3,349
# Trainable params: 3,349
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.
# Train on 100 samples
# Epoch 1/10
# 100/100 [==============================] - 0s 3ms/sample - loss: 0.7200
# Epoch 2/10
# 100/100 [==============================] - 0s 159us/sample - loss: 0.6939
# Epoch 3/10
# 100/100 [==============================] - 0s 179us/sample - loss: 0.6922
# Epoch 4/10
# 100/100 [==============================] - 0s 170us/sample - loss: 0.6920
# Epoch 5/10
# 100/100 [==============================] - 0s 160us/sample - loss: 0.6919
# Epoch 6/10
# 100/100 [==============================] - 0s 160us/sample - loss: 0.6913
# Epoch 7/10
# 100/100 [==============================] - 0s 150us/sample - loss: 0.6913
# Epoch 8/10
# 100/100 [==============================] - 0s 180us/sample - loss: 0.6908
# Epoch 9/10
# 100/100 [==============================] - 0s 150us/sample - loss: 0.6906
# Epoch 10/10
# 100/100 [==============================] - 0s 170us/sample - loss: 0.6907
